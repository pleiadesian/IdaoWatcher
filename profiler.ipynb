# %%
# %load_ext line_profiler

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %env TOKEN=301b9541eb8e20469a605257cb936b7ab0dd3e1b7cf54db0c3491615
# %env PROJPATH=/Users/pro/towh/TdxPlugin/
# %env OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES
# Out:
# env: TOKEN=301b9541eb8e20469a605257cb936b7ab0dd3e1b7cf54db0c3491615
# env: PROJPATH=/Users/pro/towh/TdxPlugin/
# env: OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES

# %%
import main as m
main = m.Main()
# %lprun -f main.mainloop main.mainloop()

# %%
import api.storage as st
storage = st.Storage()
# %lprun -f storage.get_histdata_single storage.get_histdata_single('600805.SH')

# %%
import api.storage as st
import core.realtime.explode as ex
storage = st.Storage()
time_share_explotion = ex.TimeShareExplosion()
storage.update_realtime_storage()
for code in tm.ts_mapping:
    time_share_explotion.detect_timeshare_explode(storage, code)
def traverse_all():
    for code in tm.ts_mapping:
        time_share_explotion.detect_timeshare_explode(storage, code)
# %lprun -f traverse_all traverse_all()

# %%
import core.realtime.neckline as nl
import api.storage as st
storage = st.Storage()
storage.update_realtime_storage()
neckline = nl.NeckLine(storage)
neckline.update_local_price(['600789', '000078', '300342'], [])
# %lprun -f neckline.detect_long_neckline neckline.detect_long_neckline(['600789', '000078', '300342'], [])

# %%
import util.eval_freq as ef
# ef.get_attack_distribution("/Users/pro/Nextcloud/log/20200210-utf8.log")
ef.get_attack_distribution("D:\IdaoWatcher\IdaoWatcher\log\\20200227.log")

# %%
import util.eval_freq as ef
ef.get_attack_time_list('300459',"D:\IdaoWatcher\IdaoWatcher\log\\20200227.log")
# Out:
# (['2020-02-27 09:49:01.159400',
#   '2020-02-27 09:49:39.420400',
#   '2020-02-27 09:54:27.186400',
#   '2020-02-27 09:54:48.485400',
#   '2020-02-27 10:27:55.901400',
#   '2020-02-27 10:28:02.658400',
#   '2020-02-27 10:28:06.089400',
#   '2020-02-27 10:28:09.601400',
#   '2020-02-27 10:28:24.445400'],
#  ['2020-02-27 09:31:06.819400',
#   '2020-02-27 09:35:53.901400',
#   '2020-02-27 09:43:29.537400',
#   '2020-02-27 09:48:37.610400',
#   '2020-02-27 09:49:00.346400',
#   '2020-02-27 09:49:37.921400',
#   '2020-02-27 09:50:17.021400',
#   '2020-02-27 09:50:29.545400',
#   '2020-02-27 09:53:12.179400',
#   '2020-02-27 09:54:26.793400',
#   '2020-02-27 09:54:48.087400',
#   '2020-02-27 09:54:58.562400',
#   '2020-02-27 09:55:19.550400',
#   '2020-02-27 09:55:58.847400',
#   '2020-02-27 09:59:10.344400',
#   '2020-02-27 09:59:52.761400',
#   '2020-02-27 10:01:47.808400',
#   '2020-02-27 10:04:32.195400',
#   '2020-02-27 10:18:04.602400',
#   '2020-02-27 10:19:04.730400',
#   '2020-02-27 10:19:47.235400',
#   '2020-02-27 10:26:58.731400',
#   '2020-02-27 10:27:16.418400',
#   '2020-02-27 10:27:55.091400',
#   '2020-02-27 10:28:02.226400',
#   '2020-02-27 10:28:05.691400',
#   '2020-02-27 10:28:09.189400',
#   '2020-02-27 10:28:23.666400',
#   '2020-02-27 10:29:41.260400',
#   '2020-02-27 10:31:37.568400',
#   '2020-02-27 10:31:44.582400',
#   '2020-02-27 10:31:51.655400',
#   '2020-02-27 10:31:55.167400',
#   '2020-02-27 10:31:58.797400',
#   '2020-02-27 10:32:02.353400',
#   '2020-02-27 10:47:14.117400',
#   '2020-02-27 10:47:21.222400',
#   '2020-02-27 10:47:38.671400',
#   '2020-02-27 10:47:49.332400',
#   '2020-02-27 10:47:59.983400',
#   '2020-02-27 10:48:10.464400',
#   '2020-02-27 10:48:49.101400',
#   '2020-02-27 10:49:56.067400',
#   '2020-02-27 10:50:41.909400',
#   '2020-02-27 10:52:42.887400',
#   '2020-02-27 10:54:53.797400',
#   '2020-02-27 10:56:18.856400',
#   '2020-02-27 10:56:29.460400',
#   '2020-02-27 10:56:36.461400',
#   '2020-02-27 10:56:40.083400',
#   '2020-02-27 10:56:43.515400',
#   '2020-02-27 10:56:47.047400',
#   '2020-02-27 10:56:50.384400',
#   '2020-02-27 10:56:54.085400'])

# %%
import api.storage as st
import core.realtime.open_high as oh
storage = st.Storage()
storage.update_realtime_storage()
# %lprun -f oh.detect_high_open_explosion oh.detect_high_open_explosion(storage, '603880')
