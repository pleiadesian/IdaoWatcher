# %%
# %load_ext line_profiler

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %env TOKEN=301b9541eb8e20469a605257cb936b7ab0dd3e1b7cf54db0c3491615
# %env PROJPATH=/Users/pro/towh/TdxPlugin/
# %env OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES
# Out:
# env: TOKEN=301b9541eb8e20469a605257cb936b7ab0dd3e1b7cf54db0c3491615
# env: PROJPATH=/Users/pro/towh/TdxPlugin/
# env: OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES

# %%
import main as m
main = m.Main()
# %lprun -f main.mainloop main.mainloop()

# %%
import api.storage as st
storage = st.Storage()
# %lprun -f storage.get_histdata_single storage.get_histdata_single('600805.SH')

# %%
import api.storage as st
import core.realtime.explode as ex
storage = st.Storage()
time_share_explotion = ex.TimeShareExplosion()
storage.update_realtime_storage()
for code in tm.ts_mapping:
    time_share_explotion.detect_timeshare_explode(storage, code)
def traverse_all():
    for code in tm.ts_mapping:
        time_share_explotion.detect_timeshare_explode(storage, code)
# %lprun -f traverse_all traverse_all()

# %%
import core.realtime.neckline as nl
import api.storage as st
storage = st.Storage()
storage.update_realtime_storage()
neckline = nl.NeckLine(storage)
neckline.update_local_price(['600789', '000078', '300342'], [])
# %lprun -f neckline.detect_long_neckline neckline.detect_long_neckline(['600789', '000078', '300342'], [])

# %%
import util.eval_freq as ef
ef.get_attack_distribution("/Users/pro/Nextcloud/log/20200210-utf8.log")
ef.get_attack_distribution("/Users/pro/Nextcloud/log/20200214-utf8.log")

# %%
import util.eval_freq as ef
ef.get_attack_time_list('603993',"/Users/pro/Nextcloud/log/20200214-utf8.log")
# Out:
# (['2020-02-14 09:33:08.044000',
#   '2020-02-14 09:34:18.641000',
#   '2020-02-14 09:34:57.859000',
#   '2020-02-14 09:39:37.587000',
#   '2020-02-14 09:39:41.773000',
#   '2020-02-14 09:51:15.495000',
#   '2020-02-14 09:51:19.056000',
#   '2020-02-14 10:12:46.215000',
#   '2020-02-14 10:29:04.361000',
#   '2020-02-14 13:33:53.815000',
#   '2020-02-14 13:36:36.195000',
#   '2020-02-14 14:53:30.902000'],
#  ['2020-02-14 09:33:06.864000',
#   '2020-02-14 09:34:17.256000',
#   '2020-02-14 09:34:56.579000',
#   '2020-02-14 09:39:37.126000',
#   '2020-02-14 09:39:40.638000',
#   '2020-02-14 09:41:39.753000',
#   '2020-02-14 09:41:50.265000',
#   '2020-02-14 09:43:49.538000',
#   '2020-02-14 09:46:55.405000',
#   '2020-02-14 09:47:05.908000',
#   '2020-02-14 09:51:08.060000',
#   '2020-02-14 09:51:11.541000',
#   '2020-02-14 09:51:15.036000',
#   '2020-02-14 09:51:18.554000',
#   '2020-02-14 09:51:29.058000',
#   '2020-02-14 09:53:56.327000',
#   '2020-02-14 09:55:23.923000',
#   '2020-02-14 09:55:34.413000',
#   '2020-02-14 10:00:32.371000',
#   '2020-02-14 10:06:09.159000',
#   '2020-02-14 10:06:23.168000',
#   '2020-02-14 10:12:13.816000',
#   '2020-02-14 10:12:45.393000',
#   '2020-02-14 10:14:55.166000',
#   '2020-02-14 10:14:58.687000',
#   '2020-02-14 10:27:08.155000',
#   '2020-02-14 10:29:03.890000',
#   '2020-02-14 10:29:10.820000',
#   '2020-02-14 10:29:24.907000',
#   '2020-02-14 10:29:31.937000',
#   '2020-02-14 10:29:35.439000',
#   '2020-02-14 10:29:42.475000',
#   '2020-02-14 10:29:45.974000',
#   '2020-02-14 10:34:12.613000',
#   '2020-02-14 10:35:19.253000',
#   '2020-02-14 10:36:25.934000',
#   '2020-02-14 10:36:53.843000',
#   '2020-02-14 10:56:54.715000',
#   '2020-02-14 10:57:19.367000',
#   '2020-02-14 11:04:48.864000',
#   '2020-02-14 11:04:52.363000',
#   '2020-02-14 11:04:59.456000',
#   '2020-02-14 13:09:49.323000',
#   '2020-02-14 13:21:51.174000',
#   '2020-02-14 13:33:53.350000',
#   '2020-02-14 13:36:35.407000',
#   '2020-02-14 13:47:23.449000',
#   '2020-02-14 13:47:33.927000',
#   '2020-02-14 13:47:37.515000',
#   '2020-02-14 13:47:41.015000',
#   '2020-02-14 14:53:29.929000',
#   '2020-02-14 15:00:06.447000'])

# %%
import api.storage as st
import core.realtime.open_high as oh
storage = st.Storage()
storage.update_realtime_storage()
# %lprun -f oh.detect_high_open_explosion oh.detect_high_open_explosion(storage, '603880')
