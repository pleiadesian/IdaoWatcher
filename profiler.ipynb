# %%
# %load_ext line_profiler

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %env PROJPATH=/Users/pro/towh/TdxPlugin/
# %env OBJC_DISABLE_INITIALIZE_FORK_SAFETY=YES

# %%
import main as m
main = m.Main()
# %lprun -f main.mainloop main.mainloop()

# %%
import api.storage as st
storage = st.Storage()
# %lprun -f storage.get_histdata_single storage.get_histdata_single('600805.SH')

# %%
import api.storage as st
import core.realtime.explode as ex
storage = st.Storage()
time_share_explotion = ex.TimeShareExplosion()
storage.update_realtime_storage()
for code in tm.ts_mapping:
    time_share_explotion.detect_timeshare_explode(storage, code)
def traverse_all():
    for code in tm.ts_mapping:
        time_share_explotion.detect_timeshare_explode(storage, code)
# %lprun -f traverse_all traverse_all()

# %%
import core.realtime.neckline as nl
import api.storage as st
storage = st.Storage()
storage.update_realtime_storage()
neckline = nl.NeckLine(storage)
neckline.update_local_price(['600789', '000078', '300342'], [])
# %lprun -f neckline.detect_long_neckline neckline.detect_long_neckline(['600789', '000078', '300342'], [])

# %%
import util.eval_freq as ef
ef.get_attack_distribution("/Users/pro/Nextcloud/log/20200207-utf8.log")
ef.get_attack_distribution("/Users/pro/Nextcloud/log/20200210-utf8.log")

# %%
import util.eval_freq as ef
ef.get_attack_time_list('000009',"/Users/pro/Nextcloud/log/20200210-utf8.log")
# Out:
# (['2020-02-09 19:44:55.644800',
#   '2020-02-10 09:43:27.799000',
#   '2020-02-10 09:44:16.348000',
#   '2020-02-10 09:56:16.339000',
#   '2020-02-10 09:56:44.933000',
#   '2020-02-10 09:56:59.457000',
#   '2020-02-10 10:15:15.360000',
#   '2020-02-10 10:20:19.803000',
#   '2020-02-10 10:20:26.767000',
#   '2020-02-10 11:00:46.282000',
#   '2020-02-10 11:00:49.818000',
#   '2020-02-10 11:01:10.794000',
#   '2020-02-10 11:01:15.167000',
#   '2020-02-10 14:02:56.139000',
#   '2020-02-10 14:03:49.121000'],
#  ['2020-02-10 09:40:36.971000',
#   '2020-02-10 09:41:24.110000',
#   '2020-02-10 09:43:26.836000',
#   '2020-02-10 09:44:15.877000',
#   '2020-02-10 09:56:15.425000',
#   '2020-02-10 09:56:44.169000',
#   '2020-02-10 09:56:58.681000',
#   '2020-02-10 10:15:14.943000',
#   '2020-02-10 10:20:19.077000',
#   '2020-02-10 10:20:26',
#   '2020-02-10 10:40:13.186000',
#   '2020-02-10 11:00:45.904000',
#   '2020-02-10 11:00:49.366000',
#   '2020-02-10 11:01:10.399000',
#   '2020-02-10 11:01:13.875000',
#   '2020-02-10 11:03:37.555000',
#   '2020-02-10 11:04:12.596000',
#   '2020-02-10 11:06:15.061000',
#   '2020-02-10 11:07:14.789000',
#   '2020-02-10 14:02:55.323000',
#   '2020-02-10 14:03:48.235000',
#   '2020-02-10 14:43:55.736000',
#   '2020-02-10 14:43:59.223000'])

# %%
import api.storage as st
import core.realtime.open_high as oh
storage = st.Storage()
storage.update_realtime_storage()
# %lprun -f oh.detect_high_open_explosion oh.detect_high_open_explosion(storage, '603880')
